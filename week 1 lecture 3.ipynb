# %% [markdown]
# # conditional structure
# ![image.png](attachment:image.png)

# %% [markdown]
# # Relational/ Comparison Operators
# ![image.png](attachment:image.png)

# %% [markdown]
# # IF ELSE
#
# ![image.png](attachment:image.png)
