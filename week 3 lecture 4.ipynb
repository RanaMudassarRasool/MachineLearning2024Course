# %%
import pandas as pd
df=pd.read_csv("propertydata.csv")

# %%
df.head(10)
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df.isnull().sum()
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    1
# NUM_BEDROOMS    2
# NUM_BATH        1
# SQ_FT           1
# dtype: int64

# %%
df['ST_NUM'] = df['ST_NUM'].fillna(df['ST_NUM'].mean())
df['PID'] = df['PID'].fillna(df['PID'].mean())

# %%
df.isnull().sum()
# Out:
# PID             0
# ST_NUM          0
# ST_NAME         0
# OWN_OCCUPIED    1
# NUM_BEDROOMS    2
# NUM_BATH        1
# SQ_FT           1
# dtype: int64

# %%
df.head(10)
# Out:
#            PID      ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH  \
# 0  100001000.0  104.000000      PUTNAM            Y            3        1
# 1  100002000.0  197.000000   LEXINGTON            N            3      1.5
# 2  100003000.0  191.428571   LEXINGTON            N          NaN        1
# 3  100004000.0  201.000000    BERKELEY           12            1      NaN
# 4  100005000.0  203.000000    BERKELEY            Y            3        2
# 5  100006000.0  207.000000    BERKELEY            Y          NaN        1
# 6  100007000.0  191.428571  WASHINGTON          NaN            2   HURLEY
# 7  100008000.0  213.000000     TREMONT            Y            1        1
# 8  100009000.0  215.000000     TREMONT            Y           na        2
#
#   SQ_FT
# 0  1000
# 1    --
# 2   850
# 3   700
# 4  1600
# 5   800
# 6   950
# 7   NaN
# 8  1800

# %%
df.dtypes
# Out:
# PID             float64
# ST_NUM          float64
# ST_NAME          object
# OWN_OCCUPIED     object
# NUM_BEDROOMS     object
# NUM_BATH         object
# SQ_FT            object
# dtype: object

# %%
df['NUM_BEDROOMS'] = df['NUM_BEDROOMS'].fillna(df['NUM_BEDROOMS'].mean())
df['NUM_BATH'] = df['NUM_BATH'].fillna(df['NUM_BATH'].mean())
df['SQ_FT'] = df['SQ_FT'].fillna(df['SQ_FT'].mean())

# %%
df['NUM_BEDROOMS'] = df['NUM_BEDROOMS'].fillna(df['NUM_BEDROOMS'].mean())

# %%
df['SQ_FT'] = pd.to_numeric(df['SQ_FT'], errors='coerce') 
df['NUM_BATH'] = pd.to_numeric(df['NUM_BATH'], errors='coerce')
df['NUM_BEDROOMS'] = pd.to_numeric(df['NUM_BEDROOMS'], errors='coerce')

# %%
df['OWN_OCCUPIED'] = df['OWN_OCCUPIED'].astype(object)

# %%
df['NUM_BEDROOMS'] = df['NUM_BEDROOMS'].fillna(df['NUM_BEDROOMS'].mean())
df['NUM_BATH'] = df['NUM_BATH'].fillna(df['NUM_BATH'].mean())
df['SQ_FT'] = df['SQ_FT'].fillna(df['SQ_FT'].mean())

# %%
df.head(10)
# Out:
#            PID      ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0  104.000000      PUTNAM            Y      3.000000  1.000000
# 1  100002000.0  197.000000   LEXINGTON            N      3.000000  1.500000
# 2  100003000.0  191.428571   LEXINGTON            N      2.166667  1.000000
# 3  100004000.0  201.000000    BERKELEY           12      1.000000  1.357143
# 4  100005000.0  203.000000    BERKELEY            Y      3.000000  2.000000
# 5  100006000.0  207.000000    BERKELEY            Y      2.166667  1.000000
# 6  100007000.0  191.428571  WASHINGTON          NaN      2.000000  1.357143
# 7  100008000.0  213.000000     TREMONT            Y      1.000000  1.000000
# 8  100009000.0  215.000000     TREMONT            Y      2.166667  2.000000
#
#     SQ_FT
# 0  1000.0
# 1  1100.0
# 2   850.0
# 3   700.0
# 4  1600.0
# 5   800.0
# 6   950.0
# 7  1100.0
# 8  1800.0

# %%
df = df.query("OWN_OCCUPIED == 'Y' | OWN_OCCUPIED == 'N'")

# %%
df.fillna(0, inplace=True)

# %%
df.head(10)
# Out:
#            PID      ST_NUM    ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0  100001000.0  104.000000     PUTNAM            Y      3.000000       1.0
# 1  100002000.0  197.000000  LEXINGTON            N      3.000000       1.5
# 2  100003000.0  191.428571  LEXINGTON            N      2.166667       1.0
# 4  100005000.0  203.000000   BERKELEY            Y      3.000000       2.0
# 5  100006000.0  207.000000   BERKELEY            Y      2.166667       1.0
# 7  100008000.0  213.000000    TREMONT            Y      1.000000       1.0
# 8  100009000.0  215.000000    TREMONT            Y      2.166667       2.0
#
#     SQ_FT
# 0  1000.0
# 1  1100.0
# 2   850.0
# 4  1600.0
# 5   800.0
# 7  1100.0
# 8  1800.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           7 non-null      float64
#  1   ST_NUM        7 non-null      float64
#  2   ST_NAME       7 non-null      object
#  3   OWN_OCCUPIED  7 non-null      object
#  4   NUM_BEDROOMS  7 non-null      float64
#  5   NUM_BATH      7 non-null      float64
#  6   SQ_FT         7 non-null      float64
# dtypes: float64(5), object(2)
# memory usage: 448.0+ bytes

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64'])

numeric_cols
# Out:
#            PID      ST_NUM  NUM_BEDROOMS  NUM_BATH   SQ_FT
# 0  100001000.0  104.000000      3.000000       1.0  1000.0
# 1  100002000.0  197.000000      3.000000       1.5  1100.0
# 2  100003000.0  191.428571      2.166667       1.0   850.0
# 4  100005000.0  203.000000      3.000000       2.0  1600.0
# 5  100006000.0  207.000000      2.166667       1.0   800.0
# 7  100008000.0  213.000000      1.000000       1.0  1100.0
# 8  100009000.0  215.000000      2.166667       2.0  1800.0

# %%
numeric_cols.NUM_BEDROOMS.unique()
# Out:
# array([3.        , 2.16666667, 1.        ])

# %%
df['ST_NAME'].unique()
# Out:
# array(['PUTNAM', 'LEXINGTON', 'BERKELEY', 'TREMONT'], dtype=object)
