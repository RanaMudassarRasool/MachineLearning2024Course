# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IF cond :
#    statemtnt
# elif cond :
#   statement
#   .
#   .
#   .
# else :
#   statemtn

# %%
n=0
if n > 0:
    print("number is +tive")
elif n<0 :
    print("number is -tive")
else :
    print("number is  zero")
# Out:
# number is  zero

# %%
n1=2
n2=4
op="<"

if op=="+":
    print(n1+n2)
elif op == "-" :
    print(n1-n2)
elif op== "*" :
    print(n1*n2)
elif op == "/":
    print (n1/n2)
else :
    print("wrong Input")
# Out:
# wrong Input
